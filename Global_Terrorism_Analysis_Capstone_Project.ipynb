# %% [markdown]
# <a href="https://colab.research.google.com/github/pritamgangwar/EDA-capstone-project---1/blob/main/Global_Terrorism_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/Copy of Global Terrorism Data.csv", encoding = 'ISO-8859-1')
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# **Check the names of all the columns and select out all the important columns which are needed in analysis**

# %%
pd.set_option("display.max_columns",None)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164          1.0         0      NaN
# 1    Mexico city  19.371887  -99.086624          1.0         0      NaN
# 2        Unknown  15.478598  120.599741          4.0         0      NaN
# 3         Athens  37.997490   23.762728          1.0         0      NaN
# 4        Fukouka  33.580412  130.396361          1.0         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative alternative_txt  \
# 0     NaN      1      1      1        0.0          NaN             NaN
# 1     NaN      1      1      1        0.0          NaN             NaN
# 2     NaN      1      1      1        0.0          NaN             NaN
# 3     NaN      1      1      1        0.0          NaN             NaN
# 4     NaN      1      1      1       -9.0          NaN             NaN
#
#    multiple  success  suicide  attacktype1                 attacktype1_txt  \
# 0       0.0        1        0            1                   Assassination
# 1       0.0        1        0            6     Hostage Taking (Kidnapping)
# 2       0.0        1        0            1                   Assassination
# 3       0.0        1        0            3               Bombing/Explosion
# 4       0.0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                  targtype1_txt  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                     targsubtype1_txt  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                                 gname gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#   gsubname3 motive  guncertain1  guncertain2  guncertain3  individual  nperps  \
# 0       NaN    NaN          0.0          NaN          NaN           0     NaN
# 1       NaN    NaN          0.0          NaN          NaN           0     7.0
# 2       NaN    NaN          0.0          NaN          NaN           0     NaN
# 3       NaN    NaN          0.0          NaN          NaN           0     NaN
# 4       NaN    NaN          0.0          NaN          NaN           0     NaN
#
#    nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0       NaN      NaN        NaN           NaN     NaN         NaN
# 1       NaN      NaN        NaN           NaN     NaN         NaN
# 2       NaN      NaN        NaN           NaN     NaN         NaN
# 3       NaN      NaN        NaN           NaN     NaN         NaN
# 4       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN            NaN        NaN         13
# 1            NaN     NaN         NaN            NaN        NaN         13
# 2            NaN     NaN         NaN            NaN        NaN         13
# 3            NaN     NaN         NaN            NaN        NaN          6
# 4            NaN     NaN         NaN            NaN        NaN          8
#
#   weaptype1_txt  weapsubtype1        weapsubtype1_txt  weaptype2  \
# 0       Unknown           NaN                     NaN        NaN
# 1       Unknown           NaN                     NaN        NaN
# 2       Unknown           NaN                     NaN        NaN
# 3    Explosives          16.0  Unknown Explosive Type        NaN
# 4    Incendiary           NaN                     NaN        NaN
#
#   weaptype2_txt  weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  \
# 0           NaN           NaN              NaN        NaN           NaN
# 1           NaN           NaN              NaN        NaN           NaN
# 2           NaN           NaN              NaN        NaN           NaN
# 3           NaN           NaN              NaN        NaN           NaN
# 4           NaN           NaN              NaN        NaN           NaN
#
#    weapsubtype3 weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype4_txt  weapdetail  nkill  nkillus  nkillter  nwound  nwoundus  \
# 0              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 1              NaN         NaN    0.0      NaN       NaN     0.0       NaN
# 2              NaN         NaN    1.0      NaN       NaN     0.0       NaN
# 3              NaN   Explosive    NaN      NaN       NaN     NaN       NaN
# 4              NaN  Incendiary    NaN      NaN       NaN     NaN       NaN
#
#    nwoundte  property  propextent propextent_txt  propvalue propcomment  \
# 0       NaN         0         NaN            NaN        NaN         NaN
# 1       NaN         0         NaN            NaN        NaN         NaN
# 2       NaN         0         NaN            NaN        NaN         NaN
# 3       NaN         1         NaN            NaN        NaN         NaN
# 4       NaN         1         NaN            NaN        NaN         NaN
#
#    ishostkid  nhostkid  nhostkidus  nhours  ndays divert kidhijcountry  \
# 0        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 1        1.0       1.0         0.0     NaN    NaN    NaN        Mexico
# 2        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 3        0.0       NaN         NaN     NaN    NaN    NaN           NaN
# 4        0.0       NaN         NaN     NaN    NaN    NaN           NaN
#
#    ransom  ransomamt  ransomamtus  ransompaid  ransompaidus ransomnote  \
# 0     0.0        NaN          NaN         NaN           NaN        NaN
# 1     1.0   800000.0          NaN         NaN           NaN        NaN
# 2     0.0        NaN          NaN         NaN           NaN        NaN
# 3     0.0        NaN          NaN         NaN           NaN        NaN
# 4     0.0        NaN          NaN         NaN           NaN        NaN
#
#    hostkidoutcome hostkidoutcome_txt  nreleased addnotes scite1 scite2 scite3  \
# 0             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 1             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 2             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 3             NaN                NaN        NaN      NaN    NaN    NaN    NaN
# 4             NaN                NaN        NaN      NaN    NaN    NaN    NaN
#
#   dbsource  INT_LOG  INT_IDEO  INT_MISC  INT_ANY related
# 0     PGIS        0         0         0        0     NaN
# 1     PGIS        0         1         1        1     NaN
# 2     PGIS       -9        -9         1        1     NaN
# 3     PGIS       -9        -9         1        1     NaN
# 4     PGIS       -9        -9         1        1     NaN

# %%
#Rename the columns
data.rename(columns = {'iyear':'Year', 'imonth':'Month', 'iday':'Day', 'country_txt':'Country',
                       'provstate':'state', 'region_txt':'Region', 'attacktype1_txt':'Attacktype1',
                       'target1':'Target', 'nkill':'Killed', 'nwound':'Wounded', 'summary':'Summary',
                       'weaptype1_txt':'Weapon_type', 'gname':'Group', 'motive':'Motive', 'targtype1_txt':'Target_type'}, inplace = True)
data['Casualities'] = data.Killed + data.Wounded
#filtering out the important data in whole dataset those I'am using gurther processing.
data = data[['Year', 'Casualities', 'Motive', 'Weapon_type', 'Target_type', 'city', 'latitude',
             'longitude', 'Month', 'Day', 'Country', 'state', 'Region', 'Attacktype1',
             'Group', 'Summary', 'Wounded', 'Killed', 'Target']]

# %%
data.head()
# Out:
#    Year  Casualities Motive Weapon_type                  Target_type  \
# 0  1970          1.0    NaN     Unknown  Private Citizens & Property
# 1  1970          0.0    NaN     Unknown      Government (Diplomatic)
# 2  1970          1.0    NaN     Unknown          Journalists & Media
# 3  1970          NaN    NaN  Explosives      Government (Diplomatic)
# 4  1970          NaN    NaN  Incendiary      Government (Diplomatic)
#
#             city   latitude   longitude  Month  Day             Country  \
# 0  Santo Domingo  18.456792  -69.951164      7    2  Dominican Republic
# 1    Mexico city  19.371887  -99.086624      0    0              Mexico
# 2        Unknown  15.478598  120.599741      1    0         Philippines
# 3         Athens  37.997490   23.762728      1    0              Greece
# 4        Fukouka  33.580412  130.396361      1    0               Japan
#
#      state                       Region                     Attacktype1  \
# 0      NaN  Central America & Caribbean                   Assassination
# 1  Federal                North America     Hostage Taking (Kidnapping)
# 2   Tarlac               Southeast Asia                   Assassination
# 3   Attica               Western Europe               Bombing/Explosion
# 4  Fukouka                    East Asia  Facility/Infrastructure Attack
#
#                                 Group Summary  Wounded  Killed  \
# 0                              MANO-D     NaN      0.0     1.0
# 1  23rd of September Communist League     NaN      0.0     0.0
# 2                             Unknown     NaN      0.0     1.0
# 3                             Unknown     NaN      NaN     NaN
# 4                             Unknown     NaN      NaN     NaN
#
#                     Target
# 0             Julio Guzman
# 1  Nadine Chaval, daughter
# 2                 Employee
# 3             U.S. Embassy
# 4           U.S. Consulate

# %%
data.isnull().sum() # data missing
# Out:
# Year                0
# Casualities     16874
# Motive         131130
# Weapon_type         0
# Target_type         0
# city              434
# latitude         4556
# longitude        4557
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# Attacktype1         0
# Group               0
# Summary         66129
# Wounded         16311
# Killed          10313
# Target            636
# dtype: int64

# %% [markdown]
# **Number Of Terrorist Activities Each Year**

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Year', data=data, palette='RdYlGn_r', edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities Each Year')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Number Of Casualities Each Year**

# %%
plt.subplots(figsize=(15,6))
year_cas = data.groupby('Year').Casualities.sum().to_frame().reset_index()
year_cas.columns = ['Year','Casualities']
sns.barplot(x=year_cas.Year, y=year_cas.Casualities, palette='rocket_r', edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of Casualities Each Year')
plt.show()

# %% [markdown]
# **Number Of Total Attacks In Each Country**

# %%
plt.subplots(figsize=(15,6))
country_attacks = data.Country.value_counts()[:15].reset_index()
country_attacks.columns = ['Country','Total Attacks']
sns.barplot(x=country_attacks.Country, y=country_attacks['Total Attacks'], palette='OrRd_r', edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of Total Attacks In Each Country')
plt.show()

# %% [markdown]
# **Terrorist Activities By Region In Each Year**

# %%
pd.crosstab(data.Year, data.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities By Region In Each Year')
plt.ylabel('Number Of Attacks')
plt.show()

# %% [markdown]
# **Top Countries Affected**

# %%
plt.subplots(figsize=(15,6))
sns.barplot(data['Country'].value_counts()[:15].index,data['Country'].value_counts()[:15].values,palette='coolwarm')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Counts')
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **Number Of Total Casualties In Each Countries**

# %%
plt.subplots(figsize=(15,6))
count_cas = data.groupby('Country').Casualities.sum().to_frame().reset_index().sort_values('Casualities', ascending=False)[:15]
sns.barplot(x=count_cas.Country, y=count_cas.Casualities, palette='OrRd_r',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=30)
plt.title('Number Of Total Casualties In Each Countries')
plt.show()

# %% [markdown]
# **Number Of Total Attacks In Each Region**

# %%
region_attacks = data.Region.value_counts().to_frame().reset_index()
region_attacks.columns = ['Region', 'Total Attacks']
plt.subplots(figsize=(15,6))
sns.barplot(x=region_attacks.Region, y=region_attacks['Total Attacks'], palette='vlag', edgecolor=sns.color_palette('magma',10))
plt.xticks(rotation=90)
plt.title('Number Of Total Attacks In Each Region')
plt.show()

# %% [markdown]
# **Number of Total Attacks by Attack Type**

# %%
attack_type = data.Attacktype1.value_counts().to_frame().reset_index()
attack_type.columns = ['Attack Type', 'Total Attacks']
plt.subplots(figsize=(15,6))
sns.barplot(x=attack_type['Attack Type'], y= attack_type['Total Attacks'], palette='viridis',
            edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number of Total Attacks by Attack Type')
plt.show()

# %% [markdown]
# **Number Of Total Attacks And Casualities By city**

# %%
city_attacks = data.city.value_counts().to_frame().reset_index()
city_attacks.columns = ['city', 'Total Attacks']
city_cas = data.groupby('city').Casualities.sum().to_frame().reset_index()
city_cas.columns = ['city', 'Casualities']
# city_cas.drop('Unknown', axis=0, inplace = True)
city_tot = pd.merge(city_attacks, city_cas, how='left', on='city').sort_values('Total Attacks',ascending=False)[1:21]
sns.set_palette('cubehelix')
city_tot.plot.bar(x='city', width=0.8)
plt.xticks(rotation=90)
plt.title('Number Of Total Attacks And Casualities By city')
fig = plt.gcf()
fig.set_size_inches(16,9)
plt.show()

# %% [markdown]
# **Number Of Total Attacks By Terrotist Group**

# %%
group_attacks = data.Group.value_counts().to_frame().drop('Unknown').reset_index()[:16]
group_attacks.columns = ['Terrorist Group', 'Total Attacks']
group_attacks
# Out:
#                                      Terrorist Group  Total Attacks
# 0                                            Taliban           7478
# 1        Islamic State of Iraq and the Levant (ISIL)           5613
# 2                                  Shining Path (SL)           4555
# 3   Farabundo Marti National Liberation Front (FMLN)           3351
# 4                                         Al-Shabaab           3288
# 5                            New People's Army (NPA)           2772
# 6                        Irish Republican Army (IRA)           2671
# 7      Revolutionary Armed Forces of Colombia (FARC)           2487
# 8                                         Boko Haram           2418
# 9                     Kurdistan Workers' Party (PKK)           2310
# 10               Basque Fatherland and Freedom (ETA)           2024
# 11    Communist Party of India - Maoist (CPI-Maoist)           1878
# 12                                           Maoists           1630
# 13           Liberation Tigers of Tamil Eelam (LTTE)           1606
# 14        National Liberation Army of Colombia (ELN)           1561
# 15                   Tehrik-i-Taliban Pakistan (TTP)           1351

# %%
group_attacks = data.Group.value_counts().to_frame().drop('Unknown').reset_index()[:16]
group_attacks.columns = ['Terrorist Group', 'Total Attacks']
plt.subplots(figsize = (10,8))
sns.barplot(y=group_attacks['Terrorist Group'], x=group_attacks['Total Attacks'], palette='Spectral', edgecolor=sns.color_palette('dark',10))
# plt.xticks()
plt.title('Number Of Total Attacks By Terrotist Group')
plt.show()

# %% [markdown]
# **Top Terrorist Groups Activities From 1970 to 2017**

# %%
groups_10 = data[data.Group.isin(data.Group.value_counts()[1:11].index)]
pd.crosstab(groups_10.Year, groups_10.Group).plot(color=sns.color_palette('Paired',10))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.xticks(range(1970,2017,5))
plt.ylabel('Total Attacks')
plt.title('Top Terrorist Groups Activities From 1970 to 2017')
plt.legend(labels=['Al-Shabaab',
                   'Boko Haraam',
                   'FMLN',
                   'ISIL',
                   'PKK',
                   'NPA',
                   'FARC',
                   'SL',
                   'Taliban'], loc='upper left')
plt.show()

# %% [markdown]
# **Total Number Of People Killed In Terror Attack**

# %%
killedData = data.loc[:,'Killed']
print('Number of people Killed by terror attack:', int(sum(killedData.dropna()))) # drop the NaN values
# Out:
# Number of people Killed by terror attack: 411868

# %% [markdown]
# **AttackData**

# %%
attackData = data.loc[:,'Attacktype1']
typeKillData = pd.concat([attackData, killedData], axis=1)
typeKillFormatData = typeKillData.pivot_table(columns='Attacktype1', values='Killed', aggfunc='sum')
typeKillFormatData
# Out:
# Attacktype1  Armed Assault  Assassination  Bombing/Explosion  \
# Killed            160297.0        24920.0           157321.0
#
# Attacktype1  Facility/Infrastructure Attack  Hijacking  \
# Killed                               3642.0     3718.0
#
# Attacktype1  Hostage Taking (Barricade Incident)  Hostage Taking (Kidnapping)  \
# Killed                                    4478.0                      24231.0
#
# Attacktype1  Unarmed Assault  Unknown
# Killed                 880.0  32381.0

# %% [markdown]
# **CountryData**

# %%
countryData = data.loc[:,'Country']
countryKillData = pd.concat([countryData, killedData], axis=1)
countryKillFormatData = countryKillData.pivot_table(columns='Country', values='Killed', aggfunc='sum')
countryKillFormatData
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# Killed       39384.0     42.0  11066.0      0.0  3043.0                  0.0
#
# Country  Argentina  Armenia  Australia  Austria  Azerbaijan  Bahamas  Bahrain  \
# Killed       490.0     37.0       23.0     30.0       258.0      1.0     44.0
#
# Country  Bangladesh  Barbados  Belarus  Belgium  Belize  Benin  Bhutan  \
# Killed       1244.0      76.0     14.0     79.0     3.0    0.0     9.0
#
# Country  Bolivia  Bosnia-Herzegovina  Botswana  Brazil  Brunei  Bulgaria  \
# Killed      42.0                79.0      11.0   203.0     0.0      28.0
#
# Country  Burkina Faso  Burundi  Cambodia  Cameroon  Canada  \
# Killed          134.0   4205.0     543.0    2347.0   365.0
#
# Country  Central African Republic    Chad  Chile   China  Colombia  Comoros  \
# Killed                     1990.0  1119.0  228.0  1008.0   14698.0      1.0
#
# Country  Costa Rica  Croatia  Cuba  Cyprus  Czech Republic  Czechoslovakia  \
# Killed         17.0    248.0   8.0    45.0             6.0            27.0
#
# Country  Democratic Republic of the Congo  Denmark  Djibouti  Dominica  \
# Killed                             4069.0      5.0     274.0       3.0
#
# Country  Dominican Republic  East Germany (GDR)  East Timor  Ecuador   Egypt  \
# Killed                 34.0                 2.0         9.0     54.0  3869.0
#
# Country  El Salvador  Equatorial Guinea  Eritrea  Estonia  Ethiopia  \
# Killed       12053.0                2.0     46.0      3.0    1765.0
#
# Country  Falkland Islands  Fiji  Finland  France  French Guiana  \
# Killed                0.0   8.0     11.0   534.0            1.0
#
# Country  French Polynesia  Gabon  Gambia  Georgia  Germany  Ghana  Greece  \
# Killed                0.0    6.0    13.0    278.0     84.0   19.0   325.0
#
# Country  Grenada  Guadeloupe  Guatemala  Guinea  Guinea-Bissau  Guyana  Haiti  \
# Killed       9.0         8.0     5167.0   213.0           17.0    41.0  336.0
#
# Country  Honduras  Hong Kong  Hungary  Iceland    India  Indonesia  \
# Killed      307.0        4.0      6.0      0.0  19341.0     1238.0
#
# Country  International    Iran     Iraq  Ireland  Israel  Italy  Ivory Coast  \
# Killed             1.0  1673.0  78589.0    117.0  1703.0  420.0        268.0
#
# Country  Jamaica  Japan  Jordan  Kazakhstan   Kenya  Kosovo  Kuwait  \
# Killed      42.0   66.0   133.0        39.0  1948.0    83.0    63.0
#
# Country  Kyrgyzstan  Laos  Latvia  Lebanon  Lesotho  Liberia   Libya  \
# Killed         10.0  27.0     2.0   4061.0     46.0    177.0  2598.0
#
# Country  Lithuania  Luxembourg  Macau  Macedonia  Madagascar  Malawi  \
# Killed         1.0         0.0    1.0       49.0        31.0    33.0
#
# Country  Malaysia  Maldives    Mali  Malta  Martinique  Mauritania  Mauritius  \
# Killed      152.0      20.0  1432.0    5.0         0.0        43.0        0.0
#
# Country  Mexico  Moldova  Montenegro  Morocco  Mozambique  Myanmar  Namibia  \
# Killed    780.0     13.0         1.0    292.0      2711.0   1280.0    220.0
#
# Country   Nepal  Netherlands  New Caledonia  New Hebrides  New Zealand  \
# Killed   1969.0         37.0           35.0           0.0          1.0
#
# Country  Nicaragua   Niger  Nigeria  North Korea  North Yemen  Norway  \
# Killed     10598.0  1474.0  22682.0          3.0          3.0    79.0
#
# Country  Pakistan  Panama  Papua New Guinea  Paraguay  \
# Killed    23822.0    38.0              79.0      59.0
#
# Country  People's Republic of the Congo     Peru  Philippines  Poland  \
# Killed                             15.0  12771.0       9559.0     9.0
#
# Country  Portugal  Qatar  Republic of the Congo  Rhodesia  Romania  Russia  \
# Killed       32.0    7.0                  182.0     217.0      4.0  4308.0
#
# Country  Rwanda  Saudi Arabia  Senegal  Serbia  Serbia-Montenegro  Seychelles  \
# Killed   3236.0         672.0    325.0     3.0                3.0         0.0
#
# Country  Sierra Leone  Singapore  Slovak Republic  Slovenia  Solomon Islands  \
# Killed          840.0        5.0              7.0       1.0              4.0
#
# Country  Somalia  South Africa  South Korea  South Sudan  South Vietnam  \
# Killed   10273.0        2674.0         10.0       2634.0           81.0
#
# Country  South Yemen  Soviet Union   Spain  Sri Lanka  St. Kitts and Nevis  \
# Killed           0.0          96.0  1288.0    15530.0                  0.0
#
# Country  St. Lucia   Sudan  Suriname  Swaziland  Sweden  Switzerland    Syria  \
# Killed         2.0  3883.0      29.0        6.0    22.0         74.0  15229.0
#
# Country  Taiwan  Tajikistan  Tanzania  Thailand  Togo  Trinidad and Tobago  \
# Killed     60.0       307.0      73.0    2742.0  76.0                  6.0
#
# Country  Tunisia  Turkey  Turkmenistan  Uganda  Ukraine  United Arab Emirates  \
# Killed     351.0  6888.0           3.0  3065.0   2261.0                 123.0
#
# Country  United Kingdom  United States  Uruguay  Uzbekistan  Vanuatu  \
# Killed           3410.0         3771.0      6.0        68.0      0.0
#
# Country  Vatican City  Venezuela  Vietnam  Wallis and Futuna  \
# Killed            0.0      227.0      1.0                0.0
#
# Country  West Bank and Gaza Strip  West Germany (FRG)  Western Sahara   Yemen  \
# Killed                     1500.0                97.0             1.0  8776.0
#
# Country  Yugoslavia  Zaire  Zambia  Zimbabwe
# Killed        119.0  324.0    70.0     154.0

# %% [markdown]
# **Number Of People Killed By Countries**

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size

# %%
labels = countryKillFormatData.columns.tolist()
labels = labels[:50] #50 bar provides nice view
index = np.arange(len(labels))
transpoze = countryKillFormatData.T
values = transpoze.values.tolist()
values = values[:50]
values = [int(i[0]) for i in values] # convert float to int
colors = ['red', 'green', 'blue', 'purple', 'yellow', 'brown', 'black', 'gray', 'magenta', 'orange']
fig, ax = plt.subplots(1,1)
ax.yaxis.grid(True)
fig_size = plt.rcParams["figure.figsize"]
fig_size[0]=25
fig_size[1]=25
plt.rcParams["figure.figsize"] = fig_size
plt.bar(index, values, color = colors, width = 0.9)
plt.ylabel('Killed People', fontsize = 20)
plt.xlabel('Countries', fontsize = 20)
plt.xticks(index, labels, fontsize=18, rotation=90)
plt.title('Number Of People Killed By Countries', fontsize = 20)

#print(fig_size)
plt.show()
